# %%
import pandas as pd
import numpy as np

# Создаем пример данных
data = {'Column1': np.random.rand(10),
        'Column2': np.random.randint(1, 100, 10),
        'Column3': np.random.choice(['A', 'B', 'C'], 10)}

df = pd.DataFrame(data)

# Создаем функцию форматирования для сжатия
def highlight_max(s):
    is_max = s == s.max()
    return ['font-weight: bold' if v else '' for v in is_max]

# Используем стилер для настройки визуализации
styled_df = df.style.apply(highlight_max)

# Отобразим таблицу
styled_df
# Out:
# <style type="text/css">
# #T_b6ae9_row1_col2, #T_b6ae9_row2_col0, #T_b6ae9_row5_col1, #T_b6ae9_row5_col2 {
#   font-weight: bold;
# }
# </style>
# <table id="T_b6ae9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6ae9_level0_col0" class="col_heading level0 col0" >Column1</th>
#       <th id="T_b6ae9_level0_col1" class="col_heading level0 col1" >Column2</th>
#       <th id="T_b6ae9_level0_col2" class="col_heading level0 col2" >Column3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6ae9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b6ae9_row0_col0" class="data row0 col0" >0.620770</td>
#       <td id="T_b6ae9_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_b6ae9_row0_col2" class="data row0 col2" >B</td>
#     </tr>
#     <tr>
#       <th id="T_b6ae9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b6ae9_row1_col0" class="data row1 col0" >0.600949</td>
#       <td id="T_b6ae9_row1_col1" class="data row1 col1" >51</td>
#       <td id="T_b6ae9_row1_col2" class="data row1 col2" >C</td>
#     </tr>
#     <tr>
#       <th id="T_b6ae9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b6ae9_row2_col0" class="data row2 col0" >0.942362</td>
#       <td id="T_b6ae9_row2_col1" class="data row2 col1" >11</td>
#       <td id="T_b6ae9_row2_col2" class="data row2 col2" >A</td>
#     </tr>
#     <tr>
#       <th id="T_b6ae9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b6ae9_row3_col0" class="data row3 col0" >0.701718</td>
#       <td id="T_b6ae9_row3_col1" class="data row3 col1" >82</td>
#       <td id="T_b6ae9_row3_col2" class="data row3 col2" >B</td>
#     </tr>
#     <tr>
#       <th id="T_b6ae9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b6ae9_row4_col0" class="data row4 col0" >0.634461</td>
#       <td id="T_b6ae9_row4_col1" class="data row4 col1" >62</td>
#       <td id="T_b6ae9_row4_col2" class="data row4 col2" >A</td>
#     </tr>
#     <tr>
#       <th id="T_b6ae9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b6ae9_row5_col0" class="data row5 col0" >0.700725</td>
#       <td id="T_b6ae9_row5_col1" class="data row5 col1" >88</td>
#       <td id="T_b6ae9_row5_col2" class="data row5 col2" >C</td>
#     </tr>
#     <tr>
#       <th id="T_b6ae9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b6ae9_row6_col0" class="data row6 col0" >0.493238</td>
#       <td id="T_b6ae9_row6_col1" class="data row6 col1" >74</td>
#       <td id="T_b6ae9_row6_col2" class="data row6 col2" >B</td>
#     </tr>
#     <tr>
#       <th id="T_b6ae9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b6ae9_row7_col0" class="data row7 col0" >0.297854</td>
#       <td id="T_b6ae9_row7_col1" class="data row7 col1" >87</td>
#       <td id="T_b6ae9_row7_col2" class="data row7 col2" >A</td>
#     </tr>
#     <tr>
#       <th id="T_b6ae9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b6ae9_row8_col0" class="data row8 col0" >0.156934</td>
#       <td id="T_b6ae9_row8_col1" class="data row8 col1" >26</td>
#       <td id="T_b6ae9_row8_col2" class="data row8 col2" >A</td>
#     </tr>
#     <tr>
#       <th id="T_b6ae9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b6ae9_row9_col0" class="data row9 col0" >0.693251</td>
#       <td id="T_b6ae9_row9_col1" class="data row9 col1" >81</td>
#       <td id="T_b6ae9_row9_col2" class="data row9 col2" >B</td>
#     </tr>
#   </tbody>
# </table>
